# %%
#Define the ticker list
import pandas as pd
tickers_list = ['PHO','FIW','CGW','PIO','EBLU','AQWA','IWTR']

#Fetch the data
import yfinance as yf
data = yf.download(tickers_list, '2024-1-1')['Adj Close']

#Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Close Value", fontsize=16)

#Define the labels
plt.ylabel('Cumulative Close Value', fontsize=14)
plt.xlabel('Time', fontsize=14)

#Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %%
#import package
from matplotlib import pyplot as plt

#Define the ticker list
import pandas as pd
tickers_list = ['PHO','FIW','CGW','PIO','EBLU','AQWA','IWTR']

#Fetch the data
import yfinance as yf
data = yf.download(tickers_list, '2024-1-1')['Adj Close']

#Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Close Value", fontsize=16)

#Define the labels
plt.ylabel('Cumulative Close Value', fontsize=14)
plt.xlabel('Time', fontsize=14)

#Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %%
# Set the start and end dates for your analysis. The end date is set to current day by default
start_date = '2023-01-01'
end_date = '2024-16-03'# List the ticker symbols you are interested in (as strings) 
tickers_list = ['PHO','FIW','CGW','PIO','EBLU','AQWA','IWTR']# I want to store each df separately to do Bollinger band plots later on
each_df = {}
for ticker in tickers_list:
    each_df[ticker] = data.DataReader(ticker, 'yahoo', start_date, end_date)# Concatenate dataframes for each ticker together to create a single dataframe called stocks
stocks = pd.concat(each_df, axis=1, keys = tickers)# Set names for the multi-index 
stocks.columns.names = ['Ticker Symbol','Stock Info']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_68729/3737974005.py in <module>
#       5 each_df = {}
#       6 for ticker in tickers_list:
# ----> 7     each_df[ticker] = data.DataReader(ticker, 'yahoo', start_date, end_date)# Concatenate dataframes for each ticker together to create a single dataframe called stocks
#       8 stocks = pd.concat(each_df, axis=1, keys = tickers)# Set names for the multi-index
#       9 stocks.columns.names = ['Ticker Symbol','Stock Info']
#
# NameError: name 'data' is not defined

# %%
tickers_list = ['PHO','FIW','CGW','PIO','EBLU','AQWA','IWTR']
#fetch stock news
import yfinance as yf
data = yf.download(tickers_list, '2023-1-1')['Adj Close']
from pandas_datareader.data import DataReader
import datetime
# Set the start and end dates for your analysis. The end date is set to current day by default
start_date = datetime.datetime(2023,1,1)
end_date = datetime.date.today().strftime('%Y-%m-%d')# List the ticker symbols you are interested in (as strings) 
# I want to store each df separately to do Bollinger band plots
each_df = {}
for ticker in tickers_list:
    each_df[ticker] = data.DataReader(ticker, 'yahoo', start_date, end_date)
    # Concatenate dataframes for each ticker together to create a single dataframe called stocks
stocks = pd.concat(each_df, axis=1, keys = tickers)
# Set names for the multi-index 
stocks.columns.names = ['Ticker Symbol','Stock Info']
# Out:
# [*********************100%%**********************]  7 of 7 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_94919/3334998182.py in <module>
#      11 each_df = {}
#      12 for ticker in tickers_list:
# ---> 13     each_df[ticker] = data.DataReader(ticker, 'yahoo', start_date, end_date)
#      14     # Concatenate dataframes for each ticker together to create a single dataframe called stocks
#      15 stocks = pd.concat(each_df, axis=1, keys = tickers)
#
# /opt/anaconda3/envs/data_analysis/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataReader'

# %%
data.describe()
# Out:
# Ticker       AQWA        CGW       EBLU         FIW       IWTR        PHO  \
# count   58.000000  58.000000  58.000000   58.000000  58.000000  58.000000
# mean    16.433707  52.691040  44.044405   95.581950  29.213676  61.874124
# std      0.523718   1.382664   1.364590    3.134922   0.812240   2.429566
# min     15.670000  50.570000  42.032001   90.977654  27.850000  58.432758
# 25%     15.961000  51.547501  42.849998   92.456474  28.499250  59.379329
# 50%     16.367500  52.450001  43.927000   95.863770  29.094999  62.194073
# 75%     16.925250  53.710001  45.271500   98.461699  29.982500  64.134296
# max     17.540001  55.619999  46.772999  101.870003  30.750000  66.430000
#
# Ticker        PIO
# count   58.000000
# mean    39.891975
# std      1.555709
# min     37.712765
# 25%     38.485119
# 50%     39.262465
# 75%     41.637014
# max     42.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 58 entries, 2024-01-02 to 2024-03-25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AQWA    58 non-null     float64
#  1   CGW     58 non-null     float64
#  2   EBLU    58 non-null     float64
#  3   FIW     58 non-null     float64
#  4   IWTR    57 non-null     float64
#  5   PHO     58 non-null     float64
#  6   PIO     58 non-null     float64
# dtypes: float64(7)
# memory usage: 3.6 KB

# %%
print(data.head())
# Out:
# Ticker           AQWA        CGW       EBLU        FIW       IWTR        PHO  \
# Date
# 2024-01-02  16.129999  52.430000  43.271000  94.005249  28.499001  60.320908
# 2024-01-03  15.970000  51.700001  42.706001  91.896919  28.190001  58.872326
# 2024-01-04  15.920000  51.570000  42.672001  91.727058  28.080000  58.742451
# 2024-01-05  15.850000  51.439999  42.639999  91.517220  28.090000  58.612576
# 2024-01-08  16.010000  51.889999  42.950001  92.456474  28.403000  59.172031
#
# Ticker            PIO
# Date
# 2024-01-02  39.042511
# 2024-01-03  38.322651
# 2024-01-04  38.072697
# 2024-01-05  38.022705
# 2024-01-08  38.472618

# %%
AQWA.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_94919/3930482154.py in <module>
# ----> 1 AQWA.info()
#
# NameError: name 'AQWA' is not defined

# %%
#price change in stock overtime

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr

yf.pdr_override()

# For time stamps
from datetime import datetime

tickers_list = ['PHO','FIW','CGW','PIO','EBLU','AQWA','IWTR']

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in tickers_list:
    globals()[stock] = yf.download(stock, start, end)
    
company_list = [PHO, FIW, CGW, PIO, EBLU, AQWA, IWTR]
company_name = ['PHO', 'FIW', 'CGW', 'PIO', 'EBLU', 'AQWA', 'IWTR']

for company, com_name in zip(company_list, company_name):
    company['company_name'] = com_name

df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2024-03-12  30.301001  30.301001  30.301001  30.301001  30.301001       0
# 2024-03-13  30.240000  30.240999  30.240000  30.240999  30.240999     100
# 2024-03-14  30.080999  30.160000  30.080999  30.160000  30.160000     400
# 2024-03-15  29.959999  30.090000  29.959999  30.000000  30.000000     600
# 2024-03-18  30.100000  30.100000  30.090000  30.090000  30.090000     500
# ...

# %%
IWTR.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean    28.206933   28.220092   28.176618   28.189316   27.435781
# std      1.188128    1.187772    1.166168    1.162809    1.400501
# min     25.000000   25.000000   25.000000   25.000000   24.151937
# 25%     27.737000   27.737500   27.717500   27.722000   26.725874
# 50%     28.400000   28.420000   28.379999   28.395000   27.378618
# 75%     28.831000   28.831000   28.816000   28.816000   28.293756
# max     32.506001   32.506001   30.750000   30.750000   30.750000
#
#              Volume
# count    251.000000
# mean     291.681275
# std     1356.444727
# min        0.000000
# 25%      100.000000
# 50%      100.000000
# 75%      200.000000
# max    21200.000000

# %%
FIW.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean    88.012231   88.509562   87.568088   88.077490   87.745310
# std      5.633353    5.627895    5.649345    5.664578    5.789139
# min     77.559998   78.110001   77.110001   77.300003   77.072357
# 25%     82.965000   83.564999   82.514999   83.010002   82.565449
# 50%     87.320000   87.699997   86.839996   87.370003   86.962029
# 75%     91.965000   92.484997   91.490002   91.945000   91.871941
# max    101.870003  102.040001  101.230003  101.870003  101.870003
#
#               Volume
# count     251.000000
# mean    47187.250996
# std     21803.564773
# min     13300.000000
# 25%     31600.000000
# 50%     41800.000000
# 75%     56250.000000
# max    161200.000000

# %%
FIW,info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_94919/1181880789.py in <module>
# ----> 1 FIW,info()
#
# NameError: name 'info' is not defined

# %%
FIW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2023-03-27 to 2024-03-25
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          251 non-null    float64
#  1   High          251 non-null    float64
#  2   Low           251 non-null    float64
#  3   Close         251 non-null    float64
#  4   Adj Close     251 non-null    float64
#  5   Volume        251 non-null    int64
#  6   company_name  251 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 15.7+ KB

# %%
#closing price chart
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tickers_list[i - 1]}")
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_94919/308195260.py in <module>
#       4
#       5 for i, company in enumerate(company_list, 1):
# ----> 6     plt.subplot(2, 2, i)
#       7     company['Adj Close'].plot()
#       8     plt.ylabel('Adj Close')
#
# /opt/anaconda3/envs/data_analysis/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1285
#    1286     # First, search for an existing subplot with a matching spec.
# -> 1287     key = SubplotSpec._from_subplot_args(fig, args)
#    1288
#    1289     for ax in fig.axes:
#
# /opt/anaconda3/envs/data_analysis/lib/python3.7/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     607             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
#     608                 raise ValueError(
# ...

# %%
#volume of sale chart

# Now let's plot the total volume of stock being traded each day
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tickers_list[i - 1]}")
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_94919/3728628032.py in <module>
#       6
#       7 for i, company in enumerate(company_list, 1):
# ----> 8     plt.subplot(2, 2, i)
#       9     company['Volume'].plot()
#      10     plt.ylabel('Volume')
#
# /opt/anaconda3/envs/data_analysis/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1285
#    1286     # First, search for an existing subplot with a matching spec.
# -> 1287     key = SubplotSpec._from_subplot_args(fig, args)
#    1288
#    1289     for ax in fig.axes:
#
# /opt/anaconda3/envs/data_analysis/lib/python3.7/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     607             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
#     608                 raise ValueError(
# ...

# %%
#The moving average is taken over a specific period of time, like 10 days, 20 minutes, 30 weeks, or any time period the trader chooses.

ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

PHO[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('PHO')

FIW[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('FIW')

CGW[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('CGW')

PIO[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('PIO')

fig.tight_layout()

# %%
#daily returns on avg
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

PHO['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('PHO')

FIW['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('FIW')

CGW['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('CGW')

PIO['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('PIO')

fig.tight_layout()

# %%
# Correlation is a statistic that measures the degree to which two variables move in relation to each other which has a value that must fall between -1.0 and +1.0. Correlation measures association, but doesn’t show if x causes y or vice versa — or if the association is caused by a third factor[1].



# Grab all the closing prices for the tech stock list into one DataFrame

closing_df = pdr.get_data_yahoo(tickers_list, start=start, end=end)['Adj Close']

# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# [*********************100%%**********************]  7 of 7 completed
# Ticker          AQWA       CGW      EBLU       FIW      IWTR       PHO  \
# Date
# 2023-03-27       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-03-28  0.008529  0.004382  0.000783  0.006583  0.002566  0.003873
# 2023-03-29  0.010359  0.014959  0.013792  0.010365  0.014991  0.010417
# 2023-03-30  0.005580  0.010235  0.009155  0.008427  0.011527  0.004200
# 2023-03-31  0.011861  0.010334  0.008869  0.012838  0.006980  0.014259
#
# Ticker           PIO
# Date
# 2023-03-27       NaN
# 2023-03-28  0.004731
# 2023-03-29  0.011772
# 2023-03-30  0.008726
# 2023-03-31  0.008650

# %%
#comparing stock to itself should it show a perfectly linear relationship
sns.jointplot(x='PHO', y='PHO', data=tech_rets, kind='scatter', color='seagreen')

# %%
# We'll use joinplot to compare the daily returns of PHO and FIW
sns.jointplot(x='PHO', y='FIW', data=tech_rets, kind='scatter')

# %%
# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# of all the comparisons

sns.pairplot(tech_rets, kind='reg')

# %%
#correlation plot to find correlation between all stocks 

plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
sns.heatmap(tech_rets.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock return')

plt.subplot(2, 2, 2)
sns.heatmap(closing_df.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock closing price')
# Out:
# Text(0.5, 1.0, 'Correlation of stock closing price')

# %%
#quantify risk through standard deviation 

rets = tech_rets.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 8))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %%
#predicting stock price AQWA
df = pdr.get_data_yahoo('AQWA', start='2021-01-01', end=datetime.now())
# Show teh data
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2021-04-12  15.317000  15.350000  15.317000  15.326000  14.669214     600
# 2021-04-13  15.290000  15.309000  15.220000  15.296000  14.640501    3200
# 2021-04-14  15.340000  15.357000  15.340000  15.350000  14.692186    1400
# 2021-04-15  15.810000  15.810000  15.410000  15.455000  14.792686    2700
# 2021-04-16  15.520000  17.080000  15.516000  15.590000  14.921902   13700
# ...               ...        ...        ...        ...        ...     ...
# 2024-03-19  17.028000  17.170000  17.014999  17.170000  17.170000     500
# 2024-03-20  17.120001  17.309999  17.120001  17.309999  17.309999    3200
# 2024-03-21  17.464001  17.549999  17.464001  17.540001  17.540001    4500
# 2024-03-22  17.420000  17.434999  17.420000  17.434999  17.434999     900
# 2024-03-25  17.450001  17.459000  17.340000  17.340000  17.340000    2900
#
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('AQWA Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column 
data = df.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 707

# %%
# Scale the data for more predictions
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.5654451 ],
#        [0.5598354 ],
#        [0.56993279],
#        [0.58956622],
#        [0.61480934],
#        [0.61163055],
#        [0.60639497],
#        [0.62696334],
#        [0.64846685],
#        [0.64005247],
#        [0.61948392],
#        [0.59629775],
#        [0.60546002],
#        [0.61219155],
#        [0.60321617],
#        [0.62266271],
#        [0.62789829],
#        [0.62602839],
#        [0.64734483],
#        [0.67090512],
#        [0.67894537],
#        [0.64472704],
#        [0.56993279],
#        [0.62976819],
#        [0.66660431],
#        [0.63743468],
#        [0.62958113],
#        [0.60546002],
#        [0.63724762],
#        [0.64753189],
#        [0.6602469 ],
#        [0.66062084],
#        [0.68025427],
#        [0.68866864],
#        [0.68474196],
#        [0.6989531 ],
#        [0.6952133 ],
#        [0.66810027],
#        [0.68866864],
#        [0.69614807],
#        [0.69184762],
#        [0.68586397],
#        [0.68305912],
# ...

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.5654451 , 0.5598354 , 0.56993279, 0.58956622, 0.61480934,
#        0.61163055, 0.60639497, 0.62696334, 0.64846685, 0.64005247,
#        0.61948392, 0.59629775, 0.60546002, 0.61219155, 0.60321617,
#        0.62266271, 0.62789829, 0.62602839, 0.64734483, 0.67090512,
#        0.67894537, 0.64472704, 0.56993279, 0.62976819, 0.66660431,
#        0.63743468, 0.62958113, 0.60546002, 0.63724762, 0.64753189,
#        0.6602469 , 0.66062084, 0.68025427, 0.68866864, 0.68474196,
#        0.6989531 , 0.6952133 , 0.66810027, 0.68866864, 0.69614807,
#        0.69184762, 0.68586397, 0.68305912, 0.70100988, 0.6989531 ,
#        0.71204205, 0.67258796, 0.66623037, 0.6093867 , 0.65762911,
#        0.66548248, 0.65968589, 0.63911752, 0.66810027, 0.68586397,
#        0.67127906, 0.65875094, 0.66623037, 0.68586397, 0.68025427])]
# [0.7140988311960661]
#
# [array([0.5654451 , 0.5598354 , 0.56993279, 0.58956622, 0.61480934,
#        0.61163055, 0.60639497, 0.62696334, 0.64846685, 0.64005247,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 2024-03-25 23:15:39.077247: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 647/647 [==============================] - 31s 41ms/step - loss: 0.0062

# %%
#creating possible close price 

# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 0.7491076531338806

# %%
#plotting possibles 

# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Prediction Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /opt/anaconda3/envs/data_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Show the valid and predicted prices
valid
# Out:
#                 Close  Predictions
# Date
# 2024-02-01  16.014999    15.383407
# 2024-02-02  15.958000    15.402812
# 2024-02-05  15.670000    15.421557
# 2024-02-06  15.990000    15.389567
# 2024-02-07  16.139999    15.390770
# 2024-02-08  16.270000    15.431678
# 2024-02-09  16.375000    15.507409
# 2024-02-12  16.514999    15.605130
# 2024-02-13  16.270000    15.719808
# 2024-02-14  16.360001    15.780150
# 2024-02-15  16.605000    15.816783
# 2024-02-16  16.610001    15.873342
# 2024-02-20  16.650000    15.927929
# 2024-02-21  16.530001    15.977335
# 2024-02-22  16.670000    15.993084
# 2024-02-23  16.700001    16.011707
# 2024-02-26  16.610001    16.031052
# 2024-02-27  16.750000    16.030737
# 2024-02-28  16.790001    16.043869
# 2024-02-29  16.799999    16.066517
# 2024-03-01  16.930000    16.090998
# 2024-03-04  17.040001    16.133749
# 2024-03-05  16.770000    16.195715
# 2024-03-06  16.920000    16.208790
# 2024-03-07  17.030001    16.221430
# ...
